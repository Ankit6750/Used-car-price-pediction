# %%
# import required library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
# load dataset
df=pd.read_csv('cars_data.csv')

# %%
df
# Out:
#       Unnamed: 0                     Name Transmission  \
# 0              0  2014 Maruti Swift Dzire       Manual
# 1              1        2016 Renault Kwid       Manual
# 2              2  2016 Hyundai Tucson New    Automatic
# 3              3  2010 Maruti Swift Dzire       Manual
# 4              4       2015 Renault Lodgy       Manual
# ...          ...                      ...          ...
# 4036        4036         2013 Hyundai i10       Manual
# 4037        4037     2018 Maruti Alto 800       Manual
# 4038        4038       2015 Ford New Figo       Manual
# 4039        4039    2020 Maruti Celerio X       Manual
# 4040        4040       2019 Maruti Baleno       Manual
#
#                        Model_name    km_driven      Owner Fuel_type  \
# 0                VDI BS IV Manual    67,624 km  1st Owner    Diesel
# 1                      RXT Manual    48,597 km  2nd Owner    Petrol
# 2     2WD AT GLS DIESEL Automatic  1,13,116 km  2nd Owner    Diesel
# ...

# %%
# remove unnecessary column
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#                          Name Transmission                   Model_name  \
# 0     2014 Maruti Swift Dzire       Manual             VDI BS IV Manual
# 1           2016 Renault Kwid       Manual                   RXT Manual
# 2     2016 Hyundai Tucson New    Automatic  2WD AT GLS DIESEL Automatic
# 3     2010 Maruti Swift Dzire       Manual             VDI BS IV Manual
# 4          2015 Renault Lodgy       Manual      110 PS RXZ 8 STR Manual
# ...                       ...          ...                          ...
# 4036         2013 Hyundai i10       Manual     SPORTZ 1.2 KAPPA2 Manual
# 4037     2018 Maruti Alto 800       Manual                   VXI Manual
# 4038       2015 Ford New Figo       Manual             1.5 TREND Manual
# 4039    2020 Maruti Celerio X       Manual                   Zxi Manual
# 4040       2019 Maruti Baleno       Manual          ZETA 1.2 K12 Manual
#
#         km_driven      Owner Fuel_type       Price   City
# ...

# %%
# checking duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# checking null values
df.isnull().sum()
# Out:
# Name             0
# Transmission    88
# Model_name       0
# km_driven        0
# Owner            0
# Fuel_type        0
# Price            0
# City             0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                          Name Transmission                   Model_name  \
# 0     2014 Maruti Swift Dzire       Manual             VDI BS IV Manual
# 1           2016 Renault Kwid       Manual                   RXT Manual
# 2     2016 Hyundai Tucson New    Automatic  2WD AT GLS DIESEL Automatic
# 3     2010 Maruti Swift Dzire       Manual             VDI BS IV Manual
# 4          2015 Renault Lodgy       Manual      110 PS RXZ 8 STR Manual
# ...                       ...          ...                          ...
# 4036         2013 Hyundai i10       Manual     SPORTZ 1.2 KAPPA2 Manual
# 4037     2018 Maruti Alto 800       Manual                   VXI Manual
# 4038       2015 Ford New Figo       Manual             1.5 TREND Manual
# 4039    2020 Maruti Celerio X       Manual                   Zxi Manual
# 4040       2019 Maruti Baleno       Manual          ZETA 1.2 K12 Manual
#
#         km_driven      Owner Fuel_type       Price   City
# ...

# %% [markdown]
# ### pre-processing data

# %%
df['Model_name']=df['Model_name'].str.replace('Manual','',regex=True)

# %%
df['Model_name']=df['Model_name'].str.replace('Automatic','',regex=True,)

# %%
df.replace(',','',regex=True,inplace=True)

# %%
df['km_driven']=df['km_driven'].str.replace('km','',regex=True).astype('int64')

# %%
df['Price']=df['Price'].str.replace('₹','',regex=True).astype('int64')

# %%
df
# Out:
#                          Name Transmission          Model_name  km_driven  \
# 0     2014 Maruti Swift Dzire       Manual          VDI BS IV       67624
# 1           2016 Renault Kwid       Manual                RXT       48597
# 2     2016 Hyundai Tucson New    Automatic  2WD AT GLS DIESEL      113116
# 3     2010 Maruti Swift Dzire       Manual          VDI BS IV      197455
# 4          2015 Renault Lodgy       Manual   110 PS RXZ 8 STR       34812
# ...                       ...          ...                 ...        ...
# 4036         2013 Hyundai i10       Manual  SPORTZ 1.2 KAPPA2       48659
# 4037     2018 Maruti Alto 800       Manual                VXI        2341
# 4038       2015 Ford New Figo       Manual          1.5 TREND       54018
# 4039    2020 Maruti Celerio X       Manual                Zxi       14137
# 4040       2019 Maruti Baleno       Manual       ZETA 1.2 K12       33890
#
#           Owner Fuel_type    Price   City
# ...

# %%
df.dtypes
# Out:
# Name            object
# Transmission    object
# Model_name      object
# km_driven        int64
# Owner           object
# Fuel_type       object
# Price            int64
# City            object
# dtype: object

# %%
df['mfg_year']=df['Name'].str.split().str[0].astype(int)

# %%
df['company_name']=df['Name'].str.split().str[1]

# %%
df['model']=df['Name'].str.split().str[2]

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.rename({'Model_name':'Variant'},axis=1,inplace=True)

# %%
df
# Out:
#      Transmission             Variant  km_driven      Owner Fuel_type  \
# 0          Manual          VDI BS IV       67624  1st Owner    Diesel
# 1          Manual                RXT       48597  2nd Owner    Petrol
# 2       Automatic  2WD AT GLS DIESEL      113116  2nd Owner    Diesel
# 3          Manual          VDI BS IV      197455  1st Owner    Diesel
# 4          Manual   110 PS RXZ 8 STR       34812  1st Owner    Diesel
# ...           ...                 ...        ...        ...       ...
# 4036       Manual  SPORTZ 1.2 KAPPA2       48659  2nd Owner    Petrol
# 4037       Manual                VXI        2341  1st Owner    Petrol
# 4038       Manual          1.5 TREND       54018  1st Owner    Diesel
# 4039       Manual                Zxi       14137  1st Owner    Petrol
# 4040       Manual       ZETA 1.2 K12       33890  1st Owner    Petrol
#
#         Price   City  mfg_year company_name    model
# 0      449499  Nasik      2014       Maruti    Swift
# ...

# %%
# value counts of the categorical features
df['Transmission'].value_counts().plot(kind='pie',autopct='%1.1f%%',explode=[0,0.1],figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Transmission'>

# %% [markdown]
# - Manual transmission type car mostly used

# %%
df['Owner'].value_counts().plot(kind='pie',autopct='%.1f%%',explode=[0.1,0,0,0],figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='Owner'>

# %% [markdown]
# - Most of used car selled by 1st owners

# %%
df['Fuel_type'].value_counts().plot(kind='pie',autopct='%.1f%%',figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Fuel_type'>

# %% [markdown]
# - 70% mostly petrol fuel type car are used because of less maintainance cost
# - 29% diesel fuel type car used for heavy engine like SUV,Seedan

# %%
df['City'].value_counts()
# Out:
# Mumbai        452
# Pune          450
# Bengaluru     294
# Surat         292
# Ahmedabad     292
# Chennai       277
# Jaipur        273
# Vadodara      224
# Chandigarh    169
# Ludhiana      169
# Kolkata       165
# Delhi         142
# Rohtak        137
# Panipat       136
# Meerut        130
# Kochi         120
# Nasik          64
# Nagpur         59
# Hyderabad      49
# Lucknow        41
# Patna          39
# Rajkot         23
# Mysore         20
# Bhopal         18
# Indore          6
# Name: City, dtype: int64

# %%
df['company_name'].value_counts()
# Out:
# Maruti        2199
# Hyundai        902
# Ford           265
# Honda          208
# Volkswagen      92
# Renault         81
# Toyota          77
# Tata            54
# Mahindra        40
# KIA             29
# MG              26
# Jeep            17
# Skoda           15
# Datsun          15
# BMW             10
# Nissan           4
# Audi             3
# Mercedes         3
# HYUNDAI          1
# Name: company_name, dtype: int64

# %%
df['company_name'].replace({'HYUNDAI':'Hyundai'},inplace=True)

# %%
df['model'].value_counts()
# Out:
# Alto       539
# Swift      415
# Baleno     268
# Elite      210
# Grand      210
#           ...
# Omni         1
# CRV          1
# Nano         1
# OMNI         1
# Terrano      1
# Name: model, Length: 92, dtype: int64

# %%
df['mfg_year'].value_counts()
# Out:
# 2018    805
# 2017    714
# 2019    603
# 2016    524
# 2020    386
# 2015    316
# 2014    312
# 2013    139
# 2012    119
# 2021     46
# 2011     37
# 2009     20
# 2010     17
# 2008      3
# Name: mfg_year, dtype: int64

# %%
df['Price'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### Find Insight

# %%
sale=df.groupby(['City'])['Price'].sum() # y-axis value
cities=[city for city,df in df.groupby('City')] # x-axis value

plt.figure(figsize=(10,8))
plt.bar(cities,sale,color='orange',alpha=.6)

plt.xlabel('Cities',fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Sales',fontsize=15)
plt.title('Highest  sale per price',fontsize=15)
plt.legend(['Top city sale'],loc='upper left')
plt.show()

# %% [markdown]
# - Above graph we conclude that "Mumbai and Pune" bith city are most selling used cars from cars24.com
# - Ahmedabad,surat,begaluru,jaipur,chennai are 2nd most cities of used car selling
# - Bhopal,Indore,Mysore,Rajkot,Patna in that cities used car selling is very low cars24.com has improve selling in that cities

# %%
sale_car=df.groupby(['company_name']).sum()['Price'] # y-axis value
company=[company for company,df in df.groupby('company_name')] # x-axis value

plt.figure(figsize=(10,8))
plt.bar(company,sale_car,color='green',alpha=.6)

plt.xlabel('Comapny name',fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Sale_car',fontsize=15)
plt.title('Highest  saling car company',fontsize=15)
plt.legend(['Top Sale Company'],loc='upper left')
plt.show()

# %% [markdown]
# - Maruti is top selling car company
# - Hyundai,ford,Honda sales are also good
# - Audi,BMW,Duston,Nissan,Mercesdes are very less sale in used car

# %%
sale_model=df.groupby(['model']).sum()['Price'] # y-axis value
model=[model for model,df in df.groupby('model')] # x-axis value

plt.figure(figsize=(18,8))
plt.bar(model,sale_model,color='red',alpha=.6)

plt.xlabel('model name',fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Sale_model',fontsize=15)
plt.title('Highest  saling Model',fontsize=15)
plt.legend(['Top Sale Model'],loc='upper left')
plt.show()

# %% [markdown]
# - Alto,Baleno,creta,Ecosport,Elite,Grand i10,Swift,Vitra are most selling models

# %%
plt.figure(figsize=(10,8))
plt.title('Car price range',fontsize=15)
plt.xticks(rotation=90)
sns.boxplot('company_name','Price',data=df)
# Out:
# <AxesSubplot:title={'center':'Car price range'}, xlabel='company_name', ylabel='Price'>

# %% [markdown]
# - Merceses,KIA,Audi,BMW have high range price cars

# %%
plt.figure(figsize=(10,8))
plt.title('MFG  Vs Car price',fontsize=15)
sns.lineplot(data=df,x='mfg_year',y='Price',marker=True,)
# Out:
# <AxesSubplot:title={'center':'MFG  Vs Car price'}, xlabel='mfg_year', ylabel='Price'>

# %%
# 1st owner selling price is high than price dereasing by owner increase
df_ownd = pd.DataFrame(df.groupby(['Owner'])['Price'].sum().sort_values(ascending = False))
df_ownd.plot.bar()
plt.ticklabel_format(style='plain', axis='y')
plt.title('Number of previous owners vs Average Price')
plt.show()

# %%
# diesel fuel type  cars price is high
df_fuel = pd.DataFrame(df.groupby(['Fuel_type'])['Price'].mean().sort_values(ascending = False))
df_fuel.plot.bar()
plt.ticklabel_format(style='plain', axis='y')
plt.title('Fuel Type vs Average Price')
plt.show()

# %%
# automatic transmission type cars price is high
df_trans = pd.DataFrame(df.groupby(['Transmission'])['Price'].mean().sort_values(ascending = False))
df_trans.plot.bar()
plt.ticklabel_format(style='plain', axis='y')
plt.title('Transmission Type vs Average Price')
plt.show()

# %%
# top company like audio,MG,Mercedese,KIA,JEEP,BMW are luxurious car selling company
df_vrnt = pd.DataFrame(df.groupby(['company_name'])['Price'].mean().sort_values(ascending = False))
df_vrnt.plot.bar()

plt.title('Company vs Average Price')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
df.corr()['Price']
# Out:
# km_driven   -0.033076
# Price        1.000000
# mfg_year     0.348508
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - manufaturing years are positively co-related with price which indicate manufaturing the car how old it's
# - km driven of cars are negatively co-related with price that means how car used in past

# %%
# Cnvert the engine type into range category simplify it 
df.loc[df['Variant'].str.contains('LXI',case=False),'Variant']='Basic petrol'
df.loc[df['Variant'].str.contains('VXI',case=False),'Variant']='Middle petrol'
df.loc[df['Variant'].str.contains('ZXI',case=False),'Variant']='Top petrol'
df.loc[df['Variant'].str.contains('AC PLUSHTR',case=False),'Variant']='Top petrol'
df.loc[df['Variant'].str.contains('LDI',case=False),'Variant']='Basic diesel'
df.loc[df['Variant'].str.contains('VDI',case=False),'Variant']='Middle diesel'
df.loc[df['Variant'].str.contains('ZDI',case=False),'Variant']='Top diesel'
df.loc[df['Variant'].str.contains('1.0', case=False), 'Variant'] = '1.0-1.5 Liter'
df.loc[df['Variant'].str.contains('1.1', case=False), 'Variant'] = '1.0-1.5 Liter'
df.loc[df['Variant'].str.contains('1.2', case=False), 'Variant'] = '1.0-1.5 Liter'
df.loc[df['Variant'].str.contains('1.3', case=False), 'Variant'] = '1.0-1.5 Liter'
df.loc[df['Variant'].str.contains('1.4', case=False), 'Variant'] = '1.0-1.5 Liter'
df.loc[df['Variant'].str.contains('1.5', case=False), 'Variant'] = '1.0-1.5 Liter'
df.loc[df['Variant'].str.contains('1.6', case=False), 'Variant'] = '1.5-2.0 Liter'
df.loc[df['Variant'].str.contains('1.7', case=False), 'Variant'] = '1.5-2.0 Liter'
df.loc[df['Variant'].str.contains('1.8', case=False), 'Variant'] = '1.5-2.0 Liter'
df.loc[df['Variant'].str.contains('1.9', case=False), 'Variant'] = '1.5-2.0 Liter'
df.loc[df['Variant'].str.contains('2.0', case=False), 'Variant'] = '1.5-2.0 Liter'
df.loc[df['Variant'].str.contains('2.1', case=False), 'Variant'] = '2.0-2.5 Liter'
df.loc[df['Variant'].str.contains('2.2', case=False), 'Variant'] = '2.0-2.5 Liter'
df.loc[df['Variant'].str.contains('2.3', case=False), 'Variant'] = '2.0-2.5 Liter'
df.loc[df['Variant'].str.contains('2.4', case=False), 'Variant'] = '2.02.5 Liter'
df.loc[df['Variant'].str.contains('2.5', case=False), 'Variant'] = '2.0-2.5 Liter'
df.loc[df['Variant'].str.contains('2.6', case=False), 'Variant'] = '2.5-3.0 Liter'
df.loc[df['Variant'].str.contains('2.7', case=False), 'Variant'] = '2.5-3.0 Liter'
df.loc[df['Variant'].str.contains('2.8', case=False), 'Variant'] = '2.5-3.0 Liter'
df.loc[df['Variant'].str.contains('2.9', case=False), 'Variant'] = '2.5-3.0 Liter'
df.loc[df['Variant'].str.contains('3.0', case=False), 'Variant'] = '2.5-3.0 Liter'
df.loc[df['Variant'].str.contains('3.1', case=False), 'Variant'] = '3.0+ Liter'
df.loc[df['Variant'].str.contains('3.2', case=False), 'Variant'] = '3.0+ Liter'
df.loc[df['Variant'].str.contains('3.3', case=False), 'Variant'] = '3.0+ Liter'
df.loc[df['Variant'].str.contains('3.4', case=False), 'Variant'] = '3.0+ Liter'
df.loc[df['Variant'].str.contains('3.5', case=False), 'Variant'] = '3.0+ Liter'
df.loc[df['Variant'].str.contains('LUXURY', case=False), 'Variant'] = 'Luxury'

# %%
df.loc[df['Variant'].str.contains('RXL',case=False),'Variant']='Basic petrol'
df.loc[df['Variant'].str.contains('RXT',case=False),'Variant']='Top petrol'
df.loc[df['Variant'].str.contains('PLUS',case=False),'Variant']='Top petrol'
df.loc[df['Variant'].str.contains('VX',case=False),'Variant']='Top petrol'
df.loc[df['Variant'].str.contains('V',case=False),'Variant']='Basic petrol'

# %%
df.loc[df.groupby('Variant').Variant.transform('count').lt(10), 'Variant'] = 'Other'

# %%
df['Variant'].value_counts()
# Out:
# 1.0-1.5 Liter    1596
# Middle petrol     752
# Basic petrol      421
# Middle diesel     372
# Top petrol        326
# 1.5-2.0 Liter     197
# Other             167
# Top diesel        148
# 2.0-2.5 Liter      26
# 2.5-3.0 Liter      25
# Basic diesel       11
# Name: Variant, dtype: int64

# %%
df_vrnt = pd.DataFrame(df.groupby(['Variant'])['Price'].mean().sort_values(ascending = False))
df_vrnt.plot.bar()

plt.title('Engine Type vs Average Price',fontsize=15)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
df.describe()
# Out:
#            km_driven         Price     mfg_year
# count    4041.000000  4.041000e+03  4041.000000
# mean    43628.623855  5.806407e+05  2016.896560
# std     36102.028455  2.788779e+05     2.272672
# min       120.000000  1.158990e+05  2008.000000
# 25%     17280.000000  3.937990e+05  2016.000000
# 50%     34119.000000  5.203990e+05  2017.000000
# 75%     62332.000000  6.874990e+05  2019.000000
# max    388554.000000  2.221399e+06  2021.000000

# %%
for i in df.columns:
    if df[i].dtypes != 'O':
        plt.figure()
        sns.distplot(df[i])
        plt.show()

# %% [markdown]
# - figure show that the right skewed data in price and km_driven data

# %%
df.skew()
# Out:
# km_driven    1.779342
# Price        1.971016
# mfg_year    -0.759964
# dtype: float64

# %%
# Remove skewness
df['Price']=np.log1p(df['Price'])
df['km_driven']=np.sqrt(df['km_driven'])

# %%
df.skew()
# Out:
# km_driven    0.441100
# Price        0.323944
# mfg_year    -0.759964
# dtype: float64

# %%
# checking outliers by box plot
for i in df.columns:
    if df[i].dtypes != 'O':
        plt.figure()
        df[i].plot(kind='box')
        plt.show()

# %%
# labeling the categorical data
from sklearn.preprocessing import LabelEncoder,StandardScaler
lb=LabelEncoder()
for i in df.columns:
    if df[i].dtypes == 'O':
        df[i]=lb.fit_transform(df[i])

# %%
# fill null values of transmission
df['Transmission']=df['Transmission'].fillna(df['Transmission'].mode())

# %%
df.isnull().sum()
# Out:
# Transmission    0
# Variant         0
# km_driven       0
# Owner           0
# Fuel_type       0
# Price           0
# City            0
# mfg_year        0
# company_name    0
# model           0
# dtype: int64

# %%
# spliting data in x and y
y=df['Price']
x=df.drop(columns=['Price'])

# %%
y
# Out:
# 0       13.015891
# 1       12.366915
# 2       14.045113
# 3       12.500979
# 4       13.082791
#           ...
# 4036    12.432810
# 4037    12.512457
# 4038    12.548243
# 4039    13.028272
# 4040    13.377780
# Name: Price, Length: 4041, dtype: float64

# %%
x
# Out:
#       Transmission  Variant   km_driven  Owner  Fuel_type  City  mfg_year  \
# 0                1        6  260.046150      0          0    17      2014
# 1                1       10  220.447273      1          1    17      2016
# 2                0        8  336.327222      1          0    17      2016
# 3                1        6  444.359089      0          0    17      2010
# 4                1        0  186.579742      0          0    17      2015
# ...            ...      ...         ...    ...        ...   ...       ...
# 4036             1        0  220.587851      1          1    19      2013
# 4037             1        7   48.383882      0          1    19      2018
# 4038             1        0  232.417727      0          0    19      2015
# 4039             1       10  118.899117      0          1    19      2020
# 4040             1        0  184.092368      0          1    19      2019
#
#       company_name  model
# 0               10     71
# ...

# %%
# apply scaler on countinus data
sc = StandardScaler()
x1= sc.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,SGDRegressor,ElasticNet
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV,cross_val_score
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,explained_variance_score
lr=LinearRegression()

# %%
# selecting best random state
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.3,random_state=i)
    lr.fit(x_train,y_train)
    pred_tr=lr.predict(x_train)
    pred_te=lr.predict(x_test)
    if round(r2_score(y_train,pred_tr)*100,1)== round(r2_score(y_test,pred_te)*100,1):
        print('\n Random State',i)
        print('r2_score TR',r2_score(y_train,pred_tr)*100)
        print('r2_score TE',r2_score(y_test,pred_te)*100)
# Out:
#  Random State 4
# r2_score TR 48.37175487312435
# r2_score TE 48.385433040692924
#
#  Random State 36
# r2_score TR 48.406241093630385
# r2_score TE 48.394085209199424

# %%
# spliting data into train test 
x_train, x_test, y_train, y_test = train_test_split(x1, y, test_size=0.3, random_state=4)

print("X Train Shape ",x_train.shape)
print("Y Train Shape ",y_train.shape)

print("X Test Shape ",x_test.shape)
print("Y Test Shape ",y_test.shape)
# Out:
# X Train Shape  (2828, 9)
# Y Train Shape  (2828,)
# X Test Shape  (1213, 9)
# Y Test Shape  (1213,)

# %%
# import ml library
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor

# %%
# decision tree regressor
dtr = DecisionTreeRegressor(random_state=4)
dtr.fit(x_train, y_train)
y_pred_dt = dtr.predict(x_test)
print('Train score: ',dtr.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_dt)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_dt))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_dt)))
scr = cross_val_score(dtr, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  100.0
# R2_score : 87.52875903156809
# error1:
# : 0.08256644492478864
# RSME:
# : 0.14979294003485719
# Cross value score:  83.30824628800451

# %%
# support vector regressor
svr = SVR()
svr.fit(x_train, y_train)
y_pred_sv = svr.predict(x_test)
print('Train score: ',svr.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_sv)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_sv))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_sv)))
scr = cross_val_score(svr, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  81.17937823034943
# R2_score : 74.19972365651226
# error1:
# : 0.1537735957941263
# RSME:
# : 0.2154510864178257
# Cross value score:  71.22749207701989

# %%
# Kneiarest neighbors 
knn = KNeighborsRegressor()
knn.fit(x_train, y_train)
y_pred_kn = knn.predict(x_test)
print('Train score: ',knn.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_kn)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_kn))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_kn)))
scr = cross_val_score(knn, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  81.4695656239979
# R2_score : 71.2878256627318
# error1:
# : 0.1541983384507638
# RSME:
# : 0.22728435938694197
# Cross value score:  69.3521056652047

# %%
# Random forest regressor
rfr = RandomForestRegressor(random_state=15)
rfr.fit(x_train, y_train)
y_pred_rf = rfr.predict(x_test)
print('Train score: ',rfr.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_rf)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_rf))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_rf)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_rf), 2))
scr = cross_val_score(rfr, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  98.65618433528395
# R2_score : 91.40328452273639
# error1:
# : 0.07795861596451607
# RSME:
# : 0.12436632069690802
# Explain variance score = 0.91
# Cross value score:  89.82047086694382

# %%
# hyper tunning the lasso
pr={'alpha':[0.1,0.01,0.001,0.0001,1],'fit_intercept':[True,False],'normalize':[True,False],'precompute':['auto',True,False]}
grid = GridSearchCV(Lasso(), pr,scoring="r2")
grid.fit(x1,y)
print(grid.best_params_)
# Out:
# {'alpha': 0.0001, 'fit_intercept': True, 'normalize': True, 'precompute': False}

# %%
# hyper tunning the ridge
pr={'alpha':[0.1,0.01,0.001,0.0001,1],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga','lbfgs']}
grid = GridSearchCV(Ridge(), pr,scoring="r2")
grid.fit(x1,y)
print(grid.best_params_)
# Out:
# {'alpha': 0.1, 'solver': 'saga'}

# %%
# lasso regressor
l1=Lasso(alpha=0.0001,fit_intercept=True,normalize=True,precompute=False)
l1.fit(x_train, y_train)
y_pred_l1 = l1.predict(x_test)
print('Train score: ',l1.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_l1)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_l1))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_l1)))
# Out:
# Train score:  48.233081437541045
# R2_score : 48.32271621604923
# error1:
# : 0.23311029234872185
# RSME:
# : 0.3049203073346656

# %%
# Ridge regressor
l2=Ridge(alpha=1,solver='sag')
l2.fit(x_train, y_train)
y_pred_l2 = l2.predict(x_test)
print('Train score: ',l2.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_l2)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_l2))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_l2)))
# Out:
# Train score:  48.37174023548671
# R2_score : 48.38960518794414
# error1:
# : 0.23364917804675828
# RSME:
# : 0.30472290522174966

# %%
# XGboost regressor
xg=XGBRegressor()
xg.fit(x_train, y_train)
y_pred_xg = xg.predict(x_test)
print('Train score: ',xg.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_xg)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_xg))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_xg)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_xg), 2))
# Out:
# Train score:  99.1291508149418
# R2_score : 94.48447700276058
# error1:
# : 0.06738516785197729
# RSME:
# : 0.0996161744183057
# Explain variance score = 0.95

# %%
# SGD Regressor
sd=SGDRegressor()
sd.fit(x_train, y_train)
y_pred_sd = sd.predict(x_test)
print('Train score: ',sd.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_sd)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_sd))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_sd)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_sd), 2))
scr = cross_val_score(sd, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  48.24757442691423
# R2_score : 48.23491312955445
# error1:
# : 0.2333472233669544
# RSME:
# : 0.30517923717350626
# Explain variance score = 0.48
# Cross value score:  43.79208216345381

# %%
# Ada boost regressor
adr=AdaBoostRegressor()
adr.fit(x_train, y_train)
y_pred_ad = adr.predict(x_test)
print('Train score: ',adr.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_ad)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_ad))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_ad)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_ad), 2))
scr = cross_val_score(adr, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  65.29943576486144
# R2_score : 63.19096855059569
# error1:
# : 0.20697592893915562
# RSME:
# : 0.2573437970431165
# Explain variance score = 0.64
# Cross value score:  60.45266948084781

# %%
# Gradient boosting regressor
gd=GradientBoostingRegressor()
gd.fit(x_train, y_train)
y_pred_gd = gd.predict(x_test)
print('Train score: ',gd.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_gd)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_gd))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_gd)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_gd), 2))
scr = cross_val_score(gd, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  87.6310838973211
# R2_score : 83.71178067237418
# error1:
# : 0.11786018467736281
# RSME:
# : 0.1711879983421643
# Explain variance score = 0.84
# Cross value score:  82.65310528521974

# %%
# Bagging regressor
bg=BaggingRegressor()
bg.fit(x_train, y_train)
y_pred_bg = bg.predict(x_test)
print('Train score: ',bg.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_bg)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_bg))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_bg)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_bg), 2))
scr = cross_val_score(bg, x1,y, cv=7,scoring='r2')
print('Cross value score: ',scr.mean()*100)
# Out:
# Train score:  98.16075016981023
# R2_score : 91.06140680140487
# error1:
# : 0.08120033379931384
# RSME:
# : 0.12681513719727766
# Explain variance score = 0.91
# Cross value score:  88.55319766213842

# %%
# chech cross value score
for i in range(2,11):
    crs_score=cross_val_score(xg,x1,y,cv=i,scoring='r2')
    score=crs_score.mean()
    print('cv value:',i)
    print('cross value score:',score*100)
    print('actual score:',r2_score(y_test,y_pred_rf)*100)
# Out:
# cv value: 2
# cross value score: 84.19136116563338
# actual score: 91.40328452273639
# cv value: 3
# cross value score: 89.30041942163317
# actual score: 91.40328452273639
# cv value: 4
# cross value score: 89.95390762273942
# actual score: 91.40328452273639
# cv value: 5
# cross value score: 90.28145486388006
# actual score: 91.40328452273639
# cv value: 6
# cross value score: 89.84860222782473
# actual score: 91.40328452273639
# cv value: 7
# cross value score: 91.37630620336682
# actual score: 91.40328452273639
# cv value: 8
# cross value score: 92.27941527288289
# actual score: 91.40328452273639
# cv value: 9
# cross value score: 90.11924120106849
# actual score: 91.40328452273639
# cv value: 10
# cross value score: 92.8303663039429
# actual score: 91.40328452273639

# %%
# cv score for XGboost
scr = cross_val_score(xg, x1,y, cv=7,scoring='r2')
print(scr.mean())
# Out:
# 0.9137630620336682

# %%
# Hyper tunning parameter for select model
pr={'max_depth':[3,5,7],'n_estimators':[50,70,100,300,500],'learning_rate':[0.001,0.01,0.1,],
   'subsample':[0.6,0.7,1],'colsample_bytree':[0.5,.8,1]}
grid = GridSearchCV(xg, pr,scoring="r2")
grid.fit(x1,y)
print(grid.best_params_)
# Out:
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 500, 'subsample': 0.6}

# %%
xg1=XGBRegressor(colsample_bytree=0.8,learning_rate=0.1,max_depth=7,n_estimators=500,subsample=0.6)
xg1.fit(x_train, y_train)
y_pred_xg1 = xg1.predict(x_test)
print('Train score: ',xg1.score(x_train, y_train)*100)
print('R2_score :',r2_score(y_test,y_pred_xg1)*100)
print('error1:\n:',mean_absolute_error(y_test,y_pred_xg1))
print('RSME:\n:',np.sqrt(mean_squared_error(y_test,y_pred_xg1)))
print("Explain variance score =", round(explained_variance_score(y_test, y_pred_xg1), 2))
# Out:
# Train score:  99.89767115386081
# R2_score : 93.69417762726573
# error1:
# : 0.06262646917632571
# RSME:
# : 0.10651416718848741
# Explain variance score = 0.94

# %%
# Distribution plot of Prediction
sns.distplot(y_test)
sns.distplot(xg1.predict(x_test))
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
# Regerssion plot
x=np.array(y_test)
y=np.array(xg1.predict(x_test))
plt.figure(figsize=(8,6))
plt.plot(x,y,'*')
m,b=np.polyfit(x,y,1)
plt.plot(x,m*x+b,)
plt.xlabel('Actual Values')
plt.ylabel('Prediction values')
plt.title('XGBOOST regressor',{'fontweight':'bold','fontsize':15})
# Out:
# Text(0.5, 1.0, 'XGBOOST regressor')

# %%
# saving model
import joblib
joblib.dump(xg1,'Carprice.obj')
# Out:
# ['Carprice.obj']

# %%
# Loading the saved model
model=joblib.load("Carprice.obj")

#Prediction
prediction = model.predict(x_test)

# %%
# prediction 
pd.set_option('max_columns',5000)
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Actual"])
# Out:
#                 0          1          2          3          4          5     \
# Predicted  13.858259  12.849697  13.055937  13.247395  13.064183  13.279303
# Actual     13.896998  12.899220  13.087772  13.247409  13.152116  13.335861
#
#                 6          7          8          9          10         11    \
# Predicted  13.075999  13.485873  12.816879  13.895761  13.000569  12.873230
# Actual     13.045050  13.497232  12.818552  13.912274  12.978262  12.918042
#
#                 12         13         14         15         16         17    \
# Predicted  13.392806  12.735761  13.463618  13.532036  13.556171  13.480671
# Actual     13.413689  12.777899  13.474850  13.535532  13.525960  13.470199
#
#                 18         19         20         21         22         23    \
# Predicted  12.856180  12.991911  12.955598  13.484996  12.743634  12.883997
# Actual     12.861778  12.986544  12.933621  13.470199  12.737877  12.790520
#
# ...
